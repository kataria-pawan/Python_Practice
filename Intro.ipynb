# %%
print('Hello world')
# Out:
# Hello world

# %%
a = 2
b = 3
c = a*b
print(a)
# Out:
# 2

# %%
# convert list to tuple
a = [1,2,3,4,5,6]
b = tuple(a)
print(b)
print(type(b))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
